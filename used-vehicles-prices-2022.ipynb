# %% [markdown]
# #                             # CAR PRICE PREDICTION 2022

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
df1=pd.read_csv('../input/car-price-prediction/car data.csv')
df1.head(10)

# %%
df1.shape

# %%
df1.columns

# %%
df1.info()

# %% [markdown]
# # Checking The Null Values

# %%
df1.isnull().sum()

# %%
df1['Seller_Type'].value_counts()

# %%
df1['Transmission'].value_counts()

# %%
plt.hist(df1['Fuel_Type'])
plt.show()

# %%
df1.columns

# %%
df1['Car_Name'].unique()

# %% [markdown]
# # Feature Engineering

# %%
df1['Current_Year']=2022
df1.head(11)

# %%
df1['Year'].dtype

# %%
df1['Age']=df1['Current_Year']-df1['Year']
df1.head(11)

# %%
df2=df1.drop(['Year','Current_Year','Present_Price'],axis=1)
df2.head(11)

# %%
df1['Owner'].value_counts()

# %%
plt.hist(df1['Owner'])
plt.xlabel('No of Owners')
plt.ylabel('No of Vehicles')
plt.show()
# 0 Represents=First Owner
# 1 Represents=Second Owner
# 3 Represents=Third Owner

# %%
df2.head()

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le_Fuel_Type=LabelEncoder()
le_Seller_Type=LabelEncoder()
le_Transmission=LabelEncoder()

# %%
df2['Fuel_Type_N']=le_Fuel_Type.fit_transform(df2['Fuel_Type'])
df2['Seller_Type_N']=le_Seller_Type.fit_transform(df2['Seller_Type'])
df2['Transmission_N']=le_Transmission.fit_transform(df2['Transmission'])
df2.head()

# %%
df3=df2.drop(['Fuel_Type','Seller_Type','Transmission'],axis=1)
df3.head()

# %%
df3['Selling_Price']=df3['Selling_Price']*100000
df3.head()

# %%
df3['Selling_Price'].dtype

# %%
df3['Selling_Price']=df3['Selling_Price'].astype('int32')
df3.head()

# %%
df3['Selling_Price'].max()

# %%
df3['Selling_Price'].min()

# %%
df3['Car_Name']=df3['Car_Name'].apply(lambda x:x.strip())

# %%
Counts=df3['Car_Name'].value_counts(ascending=False)
Counts

# %%
dummies=pd.get_dummies(df3['Car_Name'])
dummies.head()

# %%
dummies1=dummies.drop(['xcent'],axis=1)
dummies1.head()

# %%
df4=pd.concat([df3,dummies1],axis=1)
df4.head()

# %%
df5=df4.drop(['Car_Name'],axis=1)
df5.head()

# %%
df5.shape

# %%
x=df5.drop(['Selling_Price'],axis='columns')
x.head()

# %%
y=

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
df3.columns

# %% [markdown]
# # USING DUMMIES

# %%
dummies=pd.get_dummies(df3.Car_Name)
dummies.head()

# %%
dummies1=dummies.drop(['xcent'],axis='columns')
dummies1.head()

# %%
len(dummies1)

# %%
df4=pd.concat([x,dummies1],axis=1)
df4.head()

# %%
df5=df4.drop(['Car_Name'],axis=1)
df5.head()

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(df5,y)

# %%
def predict_price(Kms_Driven,Owner,Age,Fuel_Type_N,Seller_Type_N,Transmission):
    car_index=np.where(x.columns==Car_Name)[0][0]
    
    x=np.zeros(len(x.columns))
    x[0]=Kms_Driven
    x[1]=Owner
    x[2]=Age
    x[3]=Fuel_Type_N
    x[4]=Seller_Type_N
    if car_index>=0:
        x[car_index] =1
        
    return cr_price.predict([0])[0]

# %%
df5.head()

# %%
predict_price(27000,0,8,2,0,'800')

# %%
# FUEL TYPE
# 0 Represents=CNG, 1 Represents=Diesel, 2 Represents=Petrol

#SELLER TYPE
# 0 Represents=Dealer, 1 Represents=Individual

#TRANSMISSION
# 0 Represents=Automatic, 1 Represents=Manual

# 0 Represents=First Owner
# 1 Represents=Second Owner
# 3 Represents=Third Owner

# %%
df.head(3)

# %% [markdown]
# # Checking The Correlation

# %%
df.corr()

# %% [markdown]
# # Importing Seaborn

# %%
import seaborn as sns

# %%
sns.pairplot(df)

# %% [markdown]
# # Model Building

# %%
x=df.drop(['Car_Name','Selling_Price'],axis=1)

# %%
y=df['Selling_Price']

# %%
x

# %%
y

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)
x_test

# %%
x_train

# %%
x_test

# %%
y_train

# %%
y_test

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
model.predict(x_test)

# %% [markdown]
# # Test The Model

# %%
model.score(x_test,y_test)

# %%
model.predict([[2017,5.80,19000,0,0,0,0]])

# %%
df.loc[268]

# %%
x_test
